# %%
# Importing the necessary libraries
import pandas as pd

# %%
# To read the dataset 
df = pd.read_csv("C:/Users/rksra/OneDrive/Desktop/shalini learning/New folder (4)/New folder (4)/Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data = df.head()
data
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
print("number of rows",df.shape[0])
print("number of columns",df.shape[1])
# Out:
# number of rows 10000
# number of columns 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False    False        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data1=pd.read_csv("C:/Users/rksra/OneDrive/Desktop/shalini learning/New folder (4)/New folder (4)/Churn_Modelling.csv")
data1
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# ...

# %%
df.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male'],
#       dtype='object')

# %%
# To reduce the size of the dataset
df= data1.drop(["RowNumber", "CustomerId", "Surname"],axis=1)

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
df.mean
# Out:
# <bound method DataFrame.mean of       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# ...

# %%
df.Gender_Male
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Name: Gender_Male, Length: 10000, dtype: bool

# %%
df.median
# Out:
# <bound method DataFrame.median of       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# ...

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df ['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
# visuvalization
sns.countplot(df['Exited'])
# Out:
# <Axes: ylabel='count'>

# %%
x = df.drop('Exited', axis=1)
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88              False            False
# ...

# %%
y = df['Exited']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# to split the test_train_data
from sklearn.model_selection import train_test_split

# %%
train_test_split(x,y,test_size=0.20,random_state=42,stratify=y)
# Out:
# [      CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
#  2151          753   57       7       0.00              1          1
#  8392          739   32       3  102128.27              1          1
#  5006          755   37       0  113865.23              2          1
#  4117          561   37       5       0.00              2          1
#  7182          692   49       6  110540.43              2          0
#  ...           ...  ...     ...        ...            ...        ...
#  4555          688   35       6       0.00              1          1
#  4644          712   74       5       0.00              2          0
#  8942          667   37       9   71786.90              2          1
#  2935          687   35       8  100988.39              2          1
#  6206          802   51       7       0.00              1          0
#
#        IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42,stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.058568  ,  1.71508648,  0.68472287, ..., -0.57831252,
#         -0.57773517,  0.90750738],
#        [ 0.91362605, -0.65993547, -0.6962018 , ...,  1.72916886,
#         -0.57773517,  0.90750738],
#        [ 1.07927399, -0.18493108, -1.73189531, ...,  1.72916886,
#         -0.57773517, -1.10191942],
#        ...,
#        [ 0.16821031, -0.18493108,  1.3751852 , ..., -0.57831252,
#         -0.57773517, -1.10191942],
#        [ 0.37527024, -0.37493284,  1.02995403, ..., -0.57831252,
#          1.73089688,  0.90750738],
#        [ 1.56586482,  1.14508121,  0.68472287, ..., -0.57831252,
#          1.73089688,  0.90750738]])

# %%
x_test
# Out:
# array([[-0.68073539, -0.27993196,  0.68472287, ..., -0.57831252,
#         -0.57773517,  0.90750738],
#        [-1.30191518, -0.5649346 , -0.35097064, ...,  1.72916886,
#         -0.57773517,  0.90750738],
#        [-0.97061929,  0.10007155, -0.35097064, ..., -0.57831252,
#          1.73089688, -1.10191942],
#        ...,
#        [-1.39509214,  0.7650777 ,  1.3751852 , ...,  1.72916886,
#         -0.57773517, -1.10191942],
#        [ 0.39597623,  0.00507067,  0.68472287, ..., -0.57831252,
#         -0.57773517,  0.90750738],
#        [ 1.02750901, -0.5649346 , -1.04143297, ..., -0.57831252,
#         -0.57773517,  0.90750738]])

# %%
# !pip install imblearn

# %%
# handling imbalanced data with SMOTE
from imblearn.over_sampling import SMOTE

# %%
x_res,y_res = SMOTE().fit_resample(x,y)

# %%
x_res.value_counts()
# Out:
# CreditScore  Age  Tenure  Balance        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  Gender_Male
# 350          39   0       109733.200000  2              0          0               123602.110000    True               False            True           1
# 688          46   3       0.000000       1              0          0               84925.766816     False              True             True           1
#              41   6       129210.201980  1              1          1               45110.556922     True               False            False          1
#                   8       0.000000       1              0          0               128070.507826    False              True             True           1
#              42   1       133121.404000  1              1          0               111566.371566    True               False            True           1
# ...

# %%
y_res.value_counts()
# Out:
# Exited
# 1    7963
# 0    7963
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=0.20,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.42854597,  1.41022436,  0.44864197, ...,  1.3241616 ,
#          1.56936214,  0.80744718],
#        [ 1.09950237,  0.10739202, -1.38825824, ..., -0.75519484,
#         -0.63720156,  0.80744718],
#        [-0.81991863,  1.10957074, -0.28611812, ..., -0.75519484,
#          1.56936214, -1.2384711 ],
#        ...,
#        [ 0.20011653,  0.2076099 ,  1.18340206, ..., -0.75519484,
#         -0.63720156,  0.80744718],
#        [-0.40313007,  1.41022436,  0.44864197, ...,  1.3241616 ,
#         -0.63720156, -1.2384711 ],
#        [ 0.52916013,  1.00935287, -1.38825824, ...,  1.3241616 ,
#         -0.63720156,  0.80744718]])

# %%
x_test
# Out:
# array([[-1.2476753 , -1.19544031,  0.08126193, ..., -0.75519484,
#         -0.63720156, -1.2384711 ],
#        [-0.46893879,  0.00717415, -0.28611812, ...,  1.3241616 ,
#         -0.63720156, -1.2384711 ],
#        [ 0.34270209, -0.99500457,  1.5507821 , ..., -0.75519484,
#          1.56936214, -1.2384711 ],
#        ...,
#        [ 0.10140345, -0.29347946,  0.44864197, ..., -0.75519484,
#         -0.63720156, -1.2384711 ],
#        [ 1.11047049,  1.10957074,  0.44864197, ...,  1.3241616 ,
#         -0.63720156, -1.2384711 ],
#        [-0.38119383, -0.29347946,  1.5507821 , ...,  1.3241616 ,
#          1.56936214,  0.80744718]])

# %%
# logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
logistic = LogisticRegression()

# %%
logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = logistic.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.7727558066541117

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.7727558066541117

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.7651951375559821

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.7651951375559821

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.7701223438506117

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.7676508344030809

# %%
# knn
from sklearn.neighbors import KNeighborsClassifier

# %%
knn= KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred3 = knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.8132454488386692

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.7978855721393034

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4 = dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.8069679849340866

# %%
precision_score(y_test,y_pred4)
# Out:
# 0.7828709288299156

# %%
# random forest
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred5 = rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred5)
# Out:
# 0.8706842435655995

# %%
precision_score(y_test,y_pred5)
# Out:
# 0.868302130406714

# %%
# gradient boosting
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred6 = gbc.predict(x_test)

# %%
accuracy_score(y_test,y_pred6)
# Out:
# 0.8380414312617702

# %%
precision_score(y_test,y_pred6)
# Out:
# 0.8386675375571522

# %%
# To save the model
import joblib

# %%
filename = "finalchurm_model.sav"
joblib.dump(dt, filename)
# Out:
# ['finalchurm_model.sav']

# %%
filename = "finalchurm_model.sav"
joblib.dump(rf, filename)
# Out:
# ['finalchurm_model.sav']

# %%
filename = "finalchurm_model.sav"
joblib.dump(knn, filename)
# Out:
# ['finalchurm_model.sav']

# %%
filename = "finalchurm_model.sav"
joblib.dump(gbc, filename)
# Out:
# ['finalchurm_model.sav']

# %%
loaded_moddel = joblib.load(filename)
result = gbc.score(x_test, y_test)
print(result)
# Out:
# 0.8380414312617702

# %%
loaded_moddel = joblib.load(filename)
result = knn.score(x_test, y_test)
print(result)
# Out:
# 0.8132454488386692
